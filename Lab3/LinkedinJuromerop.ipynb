# %% [markdown]
# Link de linkedin: [Linkedin](https://www.linkedin.com/in/juan-pablo-garzon-parra-66176a218/)

# %% [markdown]
# ![Screenshot from 2022-04-19 00-19-14.png](data:image/png;base64,...)
